# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
import statsmodels.api as sm
from sklearn import datasets

# %%
csv_path = r"C:\Users\kjain307\Documents\GitHub\INST737-UniversityOfMaryland-DataScience-H1BAnalysis\Milestone2\encoding\2803clean.csv"

# %%
df1=pd.read_csv(csv_path)

# %%
#df.head(5)

# %%
# import numpy as np
# df.drop(["Unnamed: 0"], axis = 1, inplace = True) # dropping redundunt s.no

# %%
# df.reset_index(drop=True, inplace=True)

# %%
#df.head(5)

# %%
#df.describe(include="all")# include all helps to the data including irregularities like NaN

# %%
# missing_data=df.isnull()#returns True if null is present
# #missing_data.head(10)

# %%
# for column in missing_data.columns.values.tolist():
#     print(column)
#     print(missing_data[column].value_counts())
#     print("")

# %%
#df.columns

# %%
# # drop whole row with NaN in "WILLFUL_VIOLATOR" column as we have identified this column for encoding
# df.dropna(subset=["WILLFUL_VIOLATOR"], axis=0, inplace=True)
# df.dropna(subset=["EMPLOYER_STATE"], axis=0, inplace=True)
# df.dropna(subset=["PREVAILING_WAGE"], axis=0, inplace=True)
# df.dropna(subset=["PW_UNIT_OF_PAY"], axis=0, inplace=True)
# df.dropna(subset=["PW_WAGE_SOURCE_YEAR"], axis=0, inplace=True)
# df.dropna(subset=["SOC_NAME"], axis=0, inplace=True)
# df.dropna(subset=["TOTAL_WORKERS"], axis=0, inplace=True)
# df.dropna(subset=["WORKSITE_STATE"], axis=0, inplace=True)


# # reset index, because we droped two rows
# df.reset_index(drop=True, inplace=True)

# %%
# X=df[['AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_STATE',
#        'AGENT_PRESENT', 'CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED',
#        'DECISION_DATE', 'DURATION', 'EMPLOYER_ADDRESS', 'EMPLOYER_CITY',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_NAME', 'EMPLOYER_STATE',
#        'EMPLOYMENT_END_DATE', 'EMPLOYMENT_START_DATE', 'H-1B_DEPENDENT',
#        'JOB_TITLE', 'PREVAILING_WAGE', 'YEARLY_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_SOURCE_YEAR', 'SOC_CODE', 'SOC_NAME', 'TOTAL_WORKERS',
#        'VISA_CLASS', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_FROM_YEAR',
#        'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'WILLFUL_VIOLATOR',
#        'WORKSITE_CITY', 'WORKSITE_COUNTY', 'WORKSITE_POSTAL_CODE',
#        'WORKSITE_STATE']].values

# %%
# X[:1]

# %%
# df.CASE_STATUS.unique()#find unique values withinn CASE_STATUS for encoding

# %%
# le_CASE_STATUS=preprocessing.LabelEncoder()
# le_CASE_STATUS.fit(['WITHDRAWN', 'CERTIFIED', 'DENIED', 'CERTIFIED-WITHDRAWN'])
# X[:,5]=le_CASE_STATUS.transform(X[:,5])

# %%
# df.WILLFUL_VIOLATOR.unique()#find unique values withinn WILLFUL_VIOLATOR for encoding

# %%
# le_WILLFUL_VIOLATOR=preprocessing.LabelEncoder()
# le_WILLFUL_VIOLATOR.fit(['N', 'Y'])
# X[:,30]=le_WILLFUL_VIOLATOR.transform(X[:,30])

# %%
# X[0:5]

# %%
# df1=pd.DataFrame(X, columns = ['AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_STATE',
#        'AGENT_PRESENT', 'CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED',
#        'DECISION_DATE', 'DURATION', 'EMPLOYER_ADDRESS', 'EMPLOYER_CITY',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_NAME', 'EMPLOYER_STATE',
#        'EMPLOYMENT_END_DATE', 'EMPLOYMENT_START_DATE', 'H-1B_DEPENDENT',
#        'JOB_TITLE', 'PREVAILING_WAGE', 'YEARLY_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_SOURCE_YEAR', 'SOC_CODE', 'SOC_NAME', 'TOTAL_WORKERS',
#        'VISA_CLASS', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_FROM_YEAR',
#        'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'WILLFUL_VIOLATOR',
#        'WORKSITE_CITY', 'WORKSITE_COUNTY', 'WORKSITE_POSTAL_CODE',
#        'WORKSITE_STATE'])#saving encoded data into new dataframe

# %%
# df1["PREVAILING_WAGE"].head()

# %%
# df1.WORKSITE_STATE.unique()

# %%
# le_WORKSITE_STATE=preprocessing.LabelEncoder()
# le_WORKSITE_STATE.fit(['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS',
# 'KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY',
# 'NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV',
# 'WI','WY','DC','MP','GU','PR','VI','PW','MH','FM'])
# X[:,34]=le_WORKSITE_STATE.transform(X[:,34])

# %%
# X[0:2]

# %%
# df1.EMPLOYER_STATE.unique()

# %%
# le_EMPLOYER_STATE=preprocessing.LabelEncoder()
# le_EMPLOYER_STATE.fit(['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS',
# 'KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY',
# 'NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV',
# 'WI','WY','DC','MP','GU','PR','VI','PW','MH','FM'])
# X[:,13]=le_EMPLOYER_STATE.transform(X[:,13])

# %%
# X[0:2]

# %%
# df2=pd.DataFrame(X, columns = ['AGENT_ATTORNEY_CITY', 'AGENT_ATTORNEY_NAME', 'AGENT_ATTORNEY_STATE',
#        'AGENT_PRESENT', 'CASE_NUMBER', 'CASE_STATUS', 'CASE_SUBMITTED',
#        'DECISION_DATE', 'DURATION', 'EMPLOYER_ADDRESS', 'EMPLOYER_CITY',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_NAME', 'EMPLOYER_STATE',
#        'EMPLOYMENT_END_DATE', 'EMPLOYMENT_START_DATE', 'H-1B_DEPENDENT',
#        'JOB_TITLE', 'PREVAILING_WAGE', 'YEARLY_WAGE', 'PW_UNIT_OF_PAY',
#        'PW_WAGE_SOURCE_YEAR', 'SOC_CODE', 'SOC_NAME', 'TOTAL_WORKERS',
#        'VISA_CLASS', 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_FROM_YEAR',
#        'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'WILLFUL_VIOLATOR',
#        'WORKSITE_CITY', 'WORKSITE_COUNTY', 'WORKSITE_POSTAL_CODE',
#        'WORKSITE_STATE'])#saving encoded data into new dataframe

# %%
#df2.to_csv(r'C:\Users\ghasija1\Downloads\FiveYearCleanCleanEncode3.csv', encoding='utf-8')

# %%
#df.dtypes

# %%
#df1 = df.replace(np.nan, 'Empty', regex=True)
#df1.head(30)

# %%
#obj_df = df1.select_dtypes(include=['object']).copy()
#obj_df.head()
# df1["AGENT_ATTORNEY_CITY"] = df1["AGENT_ATTORNEY_CITY"].astype('category')
# WAGE_RATE_OF_PAY_FROM_YEAR

# %%
#df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Month', df1['WAGE_RATE_OF_PAY_FROM']*12,df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
#df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Week', df1['WAGE_RATE_OF_PAY_FROM']*52,df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
#df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Bi-Weekly', df1['WAGE_RATE_OF_PAY_FROM']*26,df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
#df1.dtypes

# %%
#df1['PREVAILING_WAGE']=df1['PREVAILING_WAGE'].str.replace(",","").astype(float)

# %%
#df1['YEARLY_WAGE']=df1['YEARLY_WAGE'].str.replace(",","").astype(float)

# %%
dfbeta = df1[['PREVAILING_WAGE', 'YEARLY_WAGE','PW_UNIT_OF_PAY','PW_WAGE_SOURCE_YEAR']]
dfbeta
# Out:
#         PREVAILING_WAGE                                        YEARLY_WAGE  \
# 0                 19000                                              19000
# 1                 42860                                              42860
# 2                 73965                                              73965
# 3                 65998                                              65998
# 4                 96907                                              96907
# ...                 ...                                                ...
# 1027838           33.53  33.5333.5333.5333.5333.5333.5333.5333.5333.533...
# 1027839       63,190.00                                          63,190.00
# 1027840       63,461.00                                          63,461.00
# 1027841       73,320.00                                          73,320.00
# 1027842       58,781.00                                          58,781.00
#
#         PW_UNIT_OF_PAY  PW_WAGE_SOURCE_YEAR
# 0                 Year                 2014
# 1                 Year                 2014
# 2                 Year                 2012
# 3                 Year                 2014
# 4                 Year                 2014
# ...                ...                  ...
# 1027838           Hour                 2016
# 1027839           Year                 2016
# 1027840           Year                 2016
# 1027841           Year                 2016
# 1027842           Year                 2016
#
# [1027843 rows x 4 columns]

# %%
df1['PREVAILING_WAGE']=df1['PREVAILING_WAGE'].astype(str).str.replace(",","").astype(float)
#df1['YEARLY_WAGE']=df1['YEARLY_WAGE'].astype(str).str.replace(",","").astype(float)

# %%
dfbeta = df1[['PREVAILING_WAGE', 'YEARLY_WAGE','PW_UNIT_OF_PAY','PW_WAGE_SOURCE_YEAR']]
dfbeta
# Out:
#          PREVAILING_WAGE                                        YEARLY_WAGE  \
# 0               19000.00                                              19000
# 1               42860.00                                              42860
# 2               73965.00                                              73965
# 3               65998.00                                              65998
# 4               96907.00                                              96907
# ...                  ...                                                ...
# 1027838            33.53  33.5333.5333.5333.5333.5333.5333.5333.5333.533...
# 1027839         63190.00                                          63,190.00
# 1027840         63461.00                                          63,461.00
# 1027841         73320.00                                          73,320.00
# 1027842         58781.00                                          58,781.00
#
#         PW_UNIT_OF_PAY  PW_WAGE_SOURCE_YEAR
# 0                 Year                 2014
# 1                 Year                 2014
# 2                 Year                 2012
# 3                 Year                 2014
# 4                 Year                 2014
# ...                ...                  ...
# 1027838           Hour                 2016
# 1027839           Year                 2016
# 1027840           Year                 2016
# 1027841           Year                 2016
# 1027842           Year                 2016
#
# [1027843 rows x 4 columns]

# %%
#df1['WAGE_UNIT_OF_PAY'].unique()

# %%
# df1["AGENT_ATTORNEY_CITY"] = df1["AGENT_ATTORNEY_CITY"].astype('category')
# df1["AGENT_ATTORNEY_NAME"] = df1["AGENT_ATTORNEY_NAME"].astype('category')
# df1["AGENT_ATTORNEY_STATE"] = df1["AGENT_ATTORNEY_STATE"].astype('category')
# df1["EMPLOYER_CITY"] = df1["EMPLOYER_CITY"].astype('category')
# df1["EMPLOYER_NAME"] = df1["EMPLOYER_NAME"].astype('category')
# df1["SOC_NAME"] = df1["SOC_NAME"].astype('category')
#obj_df.dtypes

# %%
# df1["AGENT_ATTORNEY_CITY_Category"] = df1["AGENT_ATTORNEY_CITY"].cat.codes
# df1["AGENT_ATTORNEY_NAME_Category"] = df1["AGENT_ATTORNEY_NAME"].cat.codes
# df1["AGENT_ATTORNEY_STATE_Category"] = df1["AGENT_ATTORNEY_STATE"].cat.codes
# df1["EMPLOYER_NAME_Category"] = df1["EMPLOYER_NAME"].cat.codes
# df1["SOC_NAME_Category"] = df1["SOC_NAME"].cat.codes
#df1.head(20)

# %%
df1['WAGE_RATE_OF_PAY_FROM']=df1['WAGE_RATE_OF_PAY_FROM'].astype(str).str.replace(",","")

# %%
df1['WAGE_RATE_OF_PAY_FROM'] = pd.to_numeric(df1['WAGE_RATE_OF_PAY_FROM'], errors='coerce')
#df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = pd.to_numeric(df1['WAGE_RATE_OF_PAY_FROM_YEAR'], errors='coerce')

# %%
# df1['AGENT_ATTORNEY_CITY_Category']=df1['AGENT_ATTORNEY_CITY_Category'].astype('category',copy=False)
# df1['AGENT_ATTORNEY_NAME_Category']=df1['AGENT_ATTORNEY_NAME_Category'].astype('category',copy=False)
# df1['AGENT_ATTORNEY_STATE_Category']=df1['AGENT_ATTORNEY_STATE_Category'].astype('category',copy=False)
# df1['EMPLOYER_NAME_Category']=df1['EMPLOYER_NAME_Category'].astype('category',copy=False)
# df1['SOC_NAME_Category']=df1['SOC_NAME_Category'].astype('category',copy=False)
# df1['CASE_STATUS']=df1['CASE_STATUS'].astype('category',copy=False)

# %%
df1.dtypes
# Out:
# Unnamed: 0                      int64
# AGENT_ATTORNEY_CITY            object
# AGENT_ATTORNEY_NAME            object
# AGENT_ATTORNEY_STATE           object
# AGENT_PRESENT                   int64
# CASE_NUMBER                    object
# CASE_STATUS                     int64
# CASE_SUBMITTED                 object
# DECISION_DATE                  object
# DURATION                        int64
# EMPLOYER_ADDRESS               object
# EMPLOYER_CITY                  object
# EMPLOYER_COUNTRY               object
# EMPLOYER_NAME                  object
# EMPLOYER_STATE                  int64
# EMPLOYMENT_END_DATE            object
# EMPLOYMENT_START_DATE          object
# H-1B_DEPENDENT                 object
# JOB_TITLE                      object
# PREVAILING_WAGE               float64
# YEARLY_WAGE                    object
# PW_UNIT_OF_PAY                 object
# PW_WAGE_SOURCE_YEAR             int64
# SOC_CODE                       object
# SOC_NAME                       object
# TOTAL_WORKERS                   int64
# VISA_CLASS                     object
# WAGE_RATE_OF_PAY_FROM         float64
# WAGE_RATE_OF_PAY_FROM_YEAR     object
# WAGE_RATE_OF_PAY_TO            object
# WAGE_UNIT_OF_PAY               object
# WILLFUL_VIOLATOR                int64
# WORKSITE_CITY                  object
# WORKSITE_COUNTY                object
# WORKSITE_POSTAL_CODE           object
# WORKSITE_STATE                  int64
# dtype: object

# %%
#a = df1['AGENT_ATTORNEY_NAME'].value_counts()

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Hour', df1['WAGE_RATE_OF_PAY_FROM']*1,df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Month', round((df1['WAGE_RATE_OF_PAY_FROM']/4/40),1),df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Week', round((df1['WAGE_RATE_OF_PAY_FROM']/40),1),df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Bi-Weekly', round((df1['WAGE_RATE_OF_PAY_FROM']/2/40),1),df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = np.where(df1['WAGE_UNIT_OF_PAY'] == 'Year', round((df1['WAGE_RATE_OF_PAY_FROM']/12/4/40),1),df1['WAGE_RATE_OF_PAY_FROM_YEAR'])

# %%
df1['WAGE_RATE_OF_PAY_FROM_YEAR'] = pd.to_numeric(df1['WAGE_RATE_OF_PAY_FROM_YEAR'], errors='coerce')

# %%
#df1.tail(20)
# Out:
#          Unnamed: 0 AGENT_ATTORNEY_CITY    AGENT_ATTORNEY_NAME  \
# 1027823     1027823              RESTON              GOEL, VIC
# 1027824     1027824          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027825     1027825          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027826     1027826          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027827     1027827                 NaN                    NaN
# 1027828     1027828          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027829     1027829              RESTON              GOEL, VIC
# 1027830     1027830            NEW YORK             JIN, QIONG
# 1027831     1027831          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027832     1027832          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027833     1027833       SAN FRANCISCO     GONZAGA, CHRISTINA
# 1027834     1027834              RESTON              GOEL, VIC
# 1027835     1027835          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027836     1027836              RESTON              GOEL, VIC
# 1027837     1027837          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027838     1027838                 NaN                    NaN
# 1027839     1027839     WEST BLOOMFIELD       SHERMAN, MICHAEL
# 1027840     1027840          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027841     1027841              RESTON              GOEL, VIC
# 1027842     1027842              RESTON              GOEL, VIC
#
#         AGENT_ATTORNEY_STATE  AGENT_PRESENT         CASE_NUMBER  CASE_STATUS  \
# 1027823                   VA              1  I-200-16252-339490            0
# 1027824                   DC              1  I-200-16252-379452            0
# 1027825                   DC              1  I-200-16252-392829            0
# 1027826                   DC              1  I-200-16252-413138            0
# 1027827                  NaN              0  I-200-16252-694539            0
# 1027828                   DC              1  I-200-16252-697857            0
# 1027829                   VA              1  I-200-16252-711766            0
# 1027830                   NY              1  I-200-16252-722572            0
# 1027831                   DC              1  I-200-16252-758636            0
# 1027832                   DC              1  I-200-16252-774076            0
# 1027833                   CA              1  I-200-16252-880737            0
# 1027834                   VA              1  I-200-16252-945530            0
# 1027835                   DC              1  I-200-16252-971453            0
# 1027836                   VA              1  I-200-16253-207542            0
# 1027837                   DC              1  I-200-16253-377234            0
# 1027838                  NaN              0  I-200-16253-389632            0
# 1027839                   MI              1  I-200-16253-408673            0
# 1027840                   DC              1  I-200-16253-507837            0
# 1027841                   VA              1  I-200-16253-591555            0
# 1027842                   VA              1  I-200-16253-658446            0
#
#         CASE_SUBMITTED DECISION_DATE  DURATION  ... VISA_CLASS  \
# 1027823       9/9/2016     9/15/2016         6  ...       H-1B
# 1027824       9/8/2016     9/14/2016         6  ...       H-1B
# 1027825       9/8/2016     9/14/2016         6  ...       H-1B
# 1027826       9/8/2016     9/14/2016         6  ...       H-1B
# 1027827       9/8/2016     9/14/2016         6  ...       H-1B
# 1027828       9/8/2016     9/14/2016         6  ...       H-1B
# 1027829       9/9/2016     9/15/2016         6  ...       H-1B
# 1027830      9/13/2016     9/19/2016         6  ...       H-1B
# 1027831      9/12/2016     9/16/2016         4  ...       H-1B
# 1027832       9/8/2016     9/14/2016         6  ...       H-1B
# 1027833       9/8/2016     9/14/2016         6  ...       H-1B
# 1027834       9/9/2016     9/15/2016         6  ...       H-1B
# 1027835       9/8/2016     9/14/2016         6  ...       H-1B
# 1027836      9/12/2016     9/16/2016         4  ...       H-1B
# 1027837       9/9/2016     9/15/2016         6  ...       H-1B
# 1027838       9/9/2016     9/15/2016         6  ...       H-1B
# 1027839       9/9/2016     9/15/2016         6  ...       H-1B
# 1027840       9/9/2016     9/15/2016         6  ...       H-1B
# 1027841      9/12/2016     9/16/2016         4  ...       H-1B
# 1027842      9/14/2016     9/20/2016         6  ...       H-1B
#
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_FROM_YEAR WAGE_RATE_OF_PAY_TO  \
# 1027823              62500.00                      32.60                 NaN
# 1027824              66477.00                      34.60                 NaN
# 1027825              60700.00                      31.60                 NaN
# 1027826              60700.00                      31.60                 NaN
# 1027827              85000.00                      44.30                 NaN
# 1027828              65645.00                      34.20                 NaN
# 1027829              63461.00                      33.10                 NaN
# 1027830              71000.00                      37.00                 NaN
# 1027831              62500.00                      32.60                 NaN
# 1027832              60100.00                      31.30                 NaN
# 1027833             105000.00                      54.70                 NaN
# 1027834              62500.00                      32.60                 NaN
# 1027835              60700.00                      31.60                 NaN
# 1027836              60700.00                      31.60                 NaN
# 1027837              73320.00                      38.20                 NaN
# 1027838                 33.53                      33.53                 NaN
# 1027839             113500.00                      59.10                 NaN
# 1027840              63461.00                      33.10                 NaN
# 1027841              73320.00                      38.20                 NaN
# 1027842              62500.00                      32.60                 NaN
#
#          WAGE_UNIT_OF_PAY WILLFUL_VIOLATOR     WORKSITE_CITY WORKSITE_COUNTY  \
# 1027823              Year                0        SAINT PAUL          DAKOTA
# 1027824              Year                0           RALEIGH            WAKE
# 1027825              Year                0        CINCINNATI        HAMILTON
# 1027826              Year                0           RARITAN        SOMERSET
# 1027827              Year                0  FARMINGTON HILLS         OAKLAND
# 1027828              Year                0            ISELIN       MIDDLESEX
# 1027829              Year                0           CHICAGO            COOK
# 1027830              Year                0          MONTVALE          BERGEN
# 1027831              Year                0           PHOENIX        MARICOPA
# 1027832              Year                0         ENGLEWOOD        ARAPAHOE
# 1027833              Year                0          MILPITAS     SANTA CLARA
# 1027834              Year                0           MALVERN         CHESTER
# 1027835              Year                0         CHARLOTTE     MECKLENBURG
# 1027836              Year                0             PLANO          COLLIN
# 1027837              Year                0           REDMOND            KING
# 1027838              Hour                0      PHILADELPHIA    PHILADELPHIA
# 1027839              Year                0            MONROE          MONROE
# 1027840              Year                0           CHICAGO            COOK
# 1027841              Year                0           REDMOND            KING
# 1027842              Year                0  COLORADO SPRINGS         EL PASO
#
#         WORKSITE_POSTAL_CODE  WORKSITE_STATE
# 1027823                55123              26
# 1027824                27604              31
# 1027825                45202              39
# 1027826                 8869              35
# 1027827                48331              25
# 1027828                 8830              35
# 1027829                60604              16
# 1027830                 7645              35
# 1027831                85027               3
# 1027832                80112               5
# 1027833                95035               4
# 1027834                19355              42
# 1027835                28255              31
# 1027836                75024              49
# 1027837                98052              54
# 1027838                19103              42
# 1027839                48162              25
# 1027840                60606              16
# 1027841                98052              54
# 1027842                80907               5
#
# [20 rows x 36 columns]

# %%
#df1.dtypes

# %%
#df1['PREVAILING_WAGE']=df1['PREVAILING_WAGE'].str.replace(",","").astype(float)

# %%
#df1.isnull().sum()

# %%
#df1.dtypes

# %%
#df1['YEARLY_WAGE']=df1['YEARLY_WAGE'].str.replace(",","").astype(float)

# %%
df1[['PREVAILING_WAGE', 'YEARLY_WAGE','PW_UNIT_OF_PAY','PW_WAGE_SOURCE_YEAR']]
# Out:
#          PREVAILING_WAGE                                        YEARLY_WAGE  \
# 0               19000.00                                              19000
# 1               42860.00                                              42860
# 2               73965.00                                              73965
# 3               65998.00                                              65998
# 4               96907.00                                              96907
# ...                  ...                                                ...
# 1027838            33.53  33.5333.5333.5333.5333.5333.5333.5333.5333.533...
# 1027839         63190.00                                          63,190.00
# 1027840         63461.00                                          63,461.00
# 1027841         73320.00                                          73,320.00
# 1027842         58781.00                                          58,781.00
#
#         PW_UNIT_OF_PAY  PW_WAGE_SOURCE_YEAR
# 0                 Year                 2014
# 1                 Year                 2014
# 2                 Year                 2012
# 3                 Year                 2014
# 4                 Year                 2014
# ...                ...                  ...
# 1027838           Hour                 2016
# 1027839           Year                 2016
# 1027840           Year                 2016
# 1027841           Year                 2016
# 1027842           Year                 2016
#
# [1027843 rows x 4 columns]

# %%
#Yearly Wage Calculation

# %%
df1['YEARLY_WAGE'] = np.where(df1['PW_UNIT_OF_PAY'] == 'Hour', round((df1['PREVAILING_WAGE']*1),1),df1['YEARLY_WAGE'])

# %%
df1['YEARLY_WAGE'] = np.where(df1['PW_UNIT_OF_PAY'] == 'Month', round((df1['PREVAILING_WAGE']/4/40),1),df1['YEARLY_WAGE'])

# %%
df1['YEARLY_WAGE'] = np.where(df1['PW_UNIT_OF_PAY'] == 'Week', round((df1['PREVAILING_WAGE']/40),1),df1['YEARLY_WAGE'])

# %%
df1['YEARLY_WAGE'] = np.where(df1['PW_UNIT_OF_PAY'] == 'Bi-Weekly', round((df1['PREVAILING_WAGE']/40/2),1),df1['YEARLY_WAGE'])

# %%
df1['YEARLY_WAGE'] = np.where(df1['PW_UNIT_OF_PAY'] == 'Year', round((df1['PREVAILING_WAGE']/12/4/40),1),df1['YEARLY_WAGE'])

# %%
df1['YEARLY_WAGE']=df1['YEARLY_WAGE'].astype(str).str.replace(",","").astype(float)

# %%
dfbeta = df1[['PREVAILING_WAGE', 'YEARLY_WAGE','PW_UNIT_OF_PAY','PW_WAGE_SOURCE_YEAR']]

# %%
#dfbeta

# %%
#df1 = df1.replace(np.nan, '', regex=True)
#dfbeta.head(20)

# %%
#df1.round({'WAGE_RATE_OF_PAY_FROM_YEAR':1})

# %%
df1.rename(columns={
    'YEARLY_WAGE':'HOURLY_WAGE',
    'WAGE_RATE_OF_PAY_FROM_YEAR':'WAGE_RATE_OF_PAY_FROM_HOURLY'
})
# Out:
#          Unnamed: 0 AGENT_ATTORNEY_CITY    AGENT_ATTORNEY_NAME  \
# 0                 0         MINNEAPOLIS        DEBRA SCHNEIDER
# 1                 1                 NaN                    NaN
# 2                 2              DALLAS            HASEENA ENU
# 3                 3          SCHAUMBURG           ELDON KAKUDA
# 4                 4          WASHINGTON        JAMES ALEXANDER
# ...             ...                 ...                    ...
# 1027838     1027838                 NaN                    NaN
# 1027839     1027839     WEST BLOOMFIELD       SHERMAN, MICHAEL
# 1027840     1027840          WASHINGTON  MUHLENKAMP, PRISCILLA
# 1027841     1027841              RESTON              GOEL, VIC
# 1027842     1027842              RESTON              GOEL, VIC
#
#         AGENT_ATTORNEY_STATE  AGENT_PRESENT         CASE_NUMBER  CASE_STATUS  \
# 0                         MN              1  I-200-09121-701936            3
# 1                        NaN              0  I-200-09146-796321            0
# 2                         TX              1  I-200-09180-329758            3
# 3                         IL              1  I-200-09183-259985            0
# 4                         DC              1  I-200-09189-800933            0
# ...                      ...            ...                 ...          ...
# 1027838                  NaN              0  I-200-16253-389632            0
# 1027839                   MI              1  I-200-16253-408673            0
# 1027840                   DC              1  I-200-16253-507837            0
# 1027841                   VA              1  I-200-16253-591555            0
# 1027842                   VA              1  I-200-16253-658446            0
#
#         CASE_SUBMITTED DECISION_DATE  DURATION  ... VISA_CLASS  \
# 0             2/5/2015      2/5/2015         0  ...       H-1B
# 1           12/12/2014    12/18/2014         6  ...       H-1B
# 2             1/3/2013    12/15/2014       711  ...       H-1B
# 3            3/10/2015     3/16/2015         6  ...       H-1B
# 4           12/17/2014    12/23/2014         6  ...       H-1B
# ...                ...           ...       ...  ...        ...
# 1027838       9/9/2016     9/15/2016         6  ...       H-1B
# 1027839       9/9/2016     9/15/2016         6  ...       H-1B
# 1027840       9/9/2016     9/15/2016         6  ...       H-1B
# 1027841      9/12/2016     9/16/2016         4  ...       H-1B
# 1027842      9/14/2016     9/20/2016         6  ...       H-1B
#
#         WAGE_RATE_OF_PAY_FROM WAGE_RATE_OF_PAY_FROM_HOURLY  \
# 0                    20000.00                        10.40
# 1                    85000.00                        44.30
# 2                    94000.00                        49.00
# 3                    66000.00                        34.40
# 4                    97000.00                        50.50
# ...                       ...                          ...
# 1027838                 33.53                        33.53
# 1027839             113500.00                        59.10
# 1027840              63461.00                        33.10
# 1027841              73320.00                        38.20
# 1027842              62500.00                        32.60
#
#         WAGE_RATE_OF_PAY_TO  WAGE_UNIT_OF_PAY WILLFUL_VIOLATOR  \
# 0                       NaN              Year                0
# 1                       NaN              Year                0
# 2                       NaN              Year                0
# 3                     70000              Year                0
# 4                    143300              Year                0
# ...                     ...               ...              ...
# 1027838                 NaN              Hour                0
# 1027839                 NaN              Year                0
# 1027840                 NaN              Year                0
# 1027841                 NaN              Year                0
# 1027842                 NaN              Year                0
#
#             WORKSITE_CITY WORKSITE_COUNTY WORKSITE_POSTAL_CODE  WORKSITE_STATE
# 0            EDEN PRAIRIE          STERNS                55412               4
# 1                  NORMAN       CLEVELAND                73019              40
# 2               SAN DIEGO       SAN DIEGO                92127               4
# 3                 HOUSTON          HARRIS                77088              49
# 4                  MCLEAN         FAIRFAX                22102              51
# ...                   ...             ...                  ...             ...
# 1027838      PHILADELPHIA    PHILADELPHIA                19103              42
# 1027839            MONROE          MONROE                48162              25
# 1027840           CHICAGO            COOK                60606              16
# 1027841           REDMOND            KING                98052              54
# 1027842  COLORADO SPRINGS         EL PASO                80907               5
#
# [1027843 rows x 36 columns]

# %%
df1.to_csv(r'C:\Users\kjain307\Documents\GitHub\INST737-UniversityOfMaryland-DataScience-H1BAnalysis\Milestone2\encoding\2803clean-new.csv', encoding='utf-8')

# %%
#df1["YEARLY_WAGE"].sort_values(ascending=False).head(50)

# %%
df2 = pd.read_csv(r'C:\Users\kjain307\Documents\GitHub\INST737-UniversityOfMaryland-DataScience-H1BAnalysis\Milestone2\encoding\2803clean-new.csv')

# %%
df2.dtypes

# %%
plt.scatter(df1.YEARLY_WAGE,df1.DURATION ,color='blue')
# plt.ylabel("DURATION")
# plt.xlabel("HOURLY_WAGE")
plt.show()
